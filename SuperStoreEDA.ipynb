# %% [markdown]
# ### Super Store EDA

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loding The Data Set

# %%
df = pd.read_excel(r"C:\Users\LENOVO\Downloads\Sample_-_Superstore.xls")

# %%
df.head()  # return first 5 rows
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()  # information about data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()  # statistical measures
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.shape  # no.of rows nd cols
# Out:
# (9994, 21)

# %%
df.drop(["Row ID","Customer ID","Postal Code"],axis = 1,inplace = True)  # drop (it is not recommended)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode    Customer Name  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class      Claire Gute
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class      Claire Gute
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class  Darrin Van Huff
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell
#
#      Segment        Country             City       State Region  \
# 0   Consumer  United States        Henderson    Kentucky  South
# 1   Consumer  United States        Henderson    Kentucky  South
# 2  Corporate  United States      Los Angeles  California   West
# 3   Consumer  United States  Fort Lauderdale     Florida  South
# 4   Consumer  United States  Fort Lauderdale     Florida  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# ### Data Cleaning
#
# * Structural Errors
# * Duplicates
# * Missing values
# * Outilers
# * Type Casting

# %% [markdown]
# ### Duplicates

# %%
df[df.duplicated()]  # duplicates
# Out:
#             Order ID Order Date  Ship Date       Ship Mode   Customer Name  \
# 3406  US-2014-150119 2014-04-23 2014-04-27  Standard Class  Laurel Beltran
#
#           Segment        Country      City State Region       Product ID  \
# 3406  Home Office  United States  Columbus  Ohio   East  FUR-CH-10002965
#
#        Category Sub-Category  \
# 3406  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
df.drop_duplicates(inplace = True)  # drop the duplicates

# %% [markdown]
# ### Missing Values

# %%
df.isna().sum()  # missing values
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### Type Casting

# %%
df.dtypes # data type of all columns
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df["Quantity"] = df["Quantity"].astype("int8")

# %% [markdown]
# ### Outliers

# %%
df.plot(kind = "box",subplots = True,layout = (3,2),figsize = (14,12))
plt.show()

# %% [markdown]
# ### Exploring The Data

# %% [markdown]
# ### Univariate Analysis:
#
# * Numerical columns  (Histogram,Box plot(For Outliers),Density Plot)
# * Categorical columns (Count Plot,Bar Plot,Pie Chart)

# %% [markdown]
# ### Numerical

# %% [markdown]
# #### Histogram

# %%
df["Sales"].plot(kind = "hist",figsize = (3,2),title = "Histogram Of Sales")
plt.xlabel("Sales")
plt.show()

# %%
df["Quantity"].plot(kind = "hist",figsize = (3,2),title = "Histogram Of Quantity")
plt.xlabel("Quantity")
plt.show()

# %%
df["Discount"].plot(kind = "hist",figsize = (3,2),title = "Histogram Of Discount")
plt.xlabel("Discount")
plt.show()

# %%
df["Profit"].plot(kind = "hist",figsize = (3,2),title = "Histogram Of Profit")
plt.xlabel("Profit")
plt.show()

# %% [markdown]
# #### Density Plot

# %%
df["Sales"].plot(kind = "density",figsize = (3,2),title = "Density Plot Of Sales")
plt.xlabel("Sales")
plt.show()

# %%
df["Quantity"].plot(kind = "density",figsize = (3,2),title = "Density Plot Of Quantity")
plt.xlabel("Quantity")
plt.show()

# %%
df["Discount"].plot(kind = "density",figsize = (3,2),title = "Density Plot Of Discount")
plt.xlabel("Discount")
plt.show()

# %%
df["Profit"].plot(kind = "density",figsize = (3,2),title = "Density Plot Of Profit")
plt.xlabel("Profit")
plt.show()

# %% [markdown]
# ### Categorical

# %% [markdown]
# #### bar plot

# %%
df["Category"].value_counts().plot(kind = "barh",xlabel = "Category",figsize = (3,2),color = ["green","orange","red"],title = "Bar Plot of Category ")
# Out:
# <Axes: title={'center': 'Bar Plot of Category '}, xlabel='Category'>

# %%
df["State"].value_counts().plot(kind = "barh",xlabel = "State",figsize = (14,12),color = ["green","orange","red"],title = "Bar Plot of States")
# Out:
# <Axes: title={'center': 'Bar Plot of States'}, xlabel='State'>

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(data = df,x = "Ship Mode")
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# #### Pie Chart

# %%
(df["Sub-Category"].value_counts()/len(df["Sub-Category"])*100).plot(kind = "pie",autopct = '%1.1f')
# Out:
# <Axes: ylabel='Sub-Category'>

# %%
(df["Region"].value_counts()/len(df["Region"])*100).plot(kind = "pie",autopct = '%1.1f',legend = True)
# Out:
# <Axes: ylabel='Region'>

# %%
(df["Category"].value_counts()/len(df["Category"])*100).plot(kind = "pie",autopct = '%1.1f',legend = True)
# Out:
# <Axes: ylabel='Category'>

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### Bivariate Analysis
#
# * Categorical & Categorical
#
# cross tab,count plot,stacked/group bar chart
#
# * Categorical & Numerical
#
# bar chart,group by,pivot,line chart
#
#
# * Numerical & Numerical
#
# correlation,scatter plot

# %% [markdown]
# ### Categorical & Categorical

# %% [markdown]
# #### Cross tab

# %%
pd.crosstab(df["Segment"],df["Category"])
# Out:
# Category     Furniture  Office Supplies  Technology
# Segment
# Consumer          1113             3127         951
# Corporate          646             1820         554
# Home Office        361             1079         342

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(data = df,x = "Ship Mode",hue = "Region")
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# ### Categorical & Numerical

# %% [markdown]
# #### Line Chart

# %%
df["Order Date"].plot(kind = "line")
# Out:
# <Axes: >

# %%
df["Ship Date"].plot(kind = "line")
# Out:
# <Axes: >

# %% [markdown]
# #### Group by

# %%
df.groupby(by = "Region")[["Segment","Quantity"]].count()
# Out:
#          Segment  Quantity
# Region
# Central     2323      2323
# East        2847      2847
# South       1620      1620
# West        3203      3203

# %% [markdown]
# #### Multivariate Analysis

# %% [markdown]
# ### Numerical & Numerical

# %% [markdown]
# #### Correlation

# %%
df.corr(numeric_only = True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200808 -0.028197  0.479067
# Quantity  0.200808  1.000000  0.008680  0.066241
# Discount -0.028197  0.008680  1.000000 -0.219481
# Profit    0.479067  0.066241 -0.219481  1.000000

# %% [markdown]
# #### Scatter Plot

# %%
df.plot("Sales","Profit",kind = "scatter",figsize = (3,2))
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
df.plot("Sales","Quantity",kind = "scatter",figsize = (3,2))
# Out:
# <Axes: xlabel='Sales', ylabel='Quantity'>

# %% [markdown]
# ### Multivariate Analysis
#
# * heatmap
# * Pairplot

# %% [markdown]
# #### heatmap

# %%
sns.heatmap(df.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# ### Conclusion:
#
# * officies supplies purchased more sales
# * california and New Yark has more states
# * consumer purchased more things compared to corporate and house office
# * In West region  ship mode is standard class in more no.of time and Central region quantity of items purchased is more
# * Correlation between Sales and Quantity is zero and Sales and Profit is moderate
# * Correlation Coefficient ranges from -0.2 to 1
