# %% [raw]
# a. Kindly fill the missing values with
# 1.value
# 2.Statistical value
# 3.Filling  method
#
# B) Create pivot table for  position and average salary.
# C) Group the data using group by as per gender  and average age

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### a. Kindly fill the missing values with

# %%
ethnic = pd.read_excel(r"C:\Users\LENOVO\Downloads\ethnic_diversity.xlsx")
ethnic
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
ethnic.isna().sum()
# Out:
# Employee_Name        0
# EmpID                0
# Position             3
# State                2
# Zip                  2
# Gender               7
# MaritalDesc          9
# CitizenDesc          3
# EmploymentStatus     0
# Department           5
# Salaries            12
# age                  0
# Race                 9
# dtype: int64

# %% [markdown]
# ### 1.value

# %%
ethnic[ethnic['Position'].isna()]  # position
# Out:
#            Employee_Name       EmpID Position State     Zip Gender  \
# 91       Desimone, Carl   1501072124      NaN    MA  2061.0     M
# 95   Kirill, Alexandra     903013071      NaN    MA  2127.0      F
# 151        Engdahl, Jean  1007020403      NaN   NaN  2026.0     M
#
#     MaritalDesc CitizenDesc        EmploymentStatus         Department  \
# 91          NaN  US Citizen                  Active                NaN
# 95      Married  US Citizen  Voluntarily Terminated  Production
# 151      Single  US Citizen                  Active  Production
#
#      Salaries  age   Race
# 91   15736.71   26  White
# 95   37619.00   44  White
# 151  49808.01   54  White

# %%
ethnic["Position"].mode()
# Out:
# 0    Production Technician I
# Name: Position, dtype: object

# %%
ethnic['Position'].fillna("Production Technician I",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['State'].isna()]  # missing value
# Out:
#       Employee_Name       EmpID                 Position State     Zip Gender  \
# 81   Liebig, Ketsia  1103024679       Production Manager   NaN  2110.0      F
# 151   Engdahl, Jean  1007020403  Production Technician I   NaN  2026.0     M
#
#     MaritalDesc CitizenDesc EmploymentStatus         Department  Salaries  \
# 81      Married  US Citizen           Active  Production         28520.00
# 151      Single  US Citizen           Active  Production         49808.01
#
#      age   Race
# 81    35  White
# 151   54  White

# %%
ethnic["State"].mode()
# Out:
# 0    MA
# Name: State, dtype: object

# %%
ethnic["State"].fillna("MA",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Zip'].isna()]  # Zip ---missing values
# Out:
#           Employee_Name       EmpID                 Position State  Zip  \
# 83   Peterson, Ebonee    1402065355       Production Manager    MA  NaN
# 146    Sutwell, Barbara  1407069061  Production Technician I    MA  NaN
#
#     Gender MaritalDesc          CitizenDesc        EmploymentStatus  \
# 83       F     Married           US Citizen  Voluntarily Terminated
# 146    NaN      Single  Eligible NonCitizen                  Active
#
#             Department  Salaries  age   Race
# 83   Production         37487.05   27  White
# 146  Production         22626.11   45  Asian

# %%
ethnic["Zip"].mode()
# Out:
# 0    1886.0
# Name: Zip, dtype: float64

# %%
ethnic['Zip'].fillna(1886.0,inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Gender'].isna()]  # Gender ---- missing values
# Out:
#             Employee_Name       EmpID                 Position State      Zip  \
# 26        Martins, Joseph  1209048771       Area Sales Manager    TX  78207.0
# 146      Sutwell, Barbara  1407069061  Production Technician I    MA   1886.0
# 150        Cornett, Lisa   1403066069  Production Technician I    MA   2189.0
# 166     Dickinson, Geoff    706006285  Production Technician I    MA   2180.0
# 186        Mckenna, Sandy   909015167  Production Technician I    MA   2184.0
# 202     Linares, Marilyn   1206042315  Production Technician I    MA   1886.0
# 216  Kinsella, Kathleen     710007401  Production Technician I    MA   2170.0
#
#     Gender MaritalDesc          CitizenDesc        EmploymentStatus  \
# 26     NaN      Single  Eligible NonCitizen                  Active
# 146    NaN      Single  Eligible NonCitizen                  Active
# 150    NaN     Married           US Citizen                  Active
# 166    NaN      Single           US Citizen                  Active
# ...

# %%
ethnic["Gender"].mode()
# Out:
# 0    F
# Name: Gender, dtype: object

# %%
ethnic['Gender'].fillna("F",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['MaritalDesc'].isna()]  # MaritalDesc --- missing values
# Out:
#             Employee_Name       EmpID                 Position State      Zip  \
# 32       Terry, Sharlene   1401064637       Area Sales Manager    OR  97756.0
# 48            Roby, Lori   1407068885             Data Analyst    MA   1886.0
# 70        Shepard, Anita    906014183         Network Engineer    MA   1773.0
# 91        Desimone, Carl   1501072124  Production Technician I    MA   2061.0
# 112        Ngodup, Shari   1403066020  Production Technician I    MA   1810.0
# 134   Beatrice, Courtney   1403066194  Production Technician I    MA   1915.0
# 161          Stoica, Rick  1106026896  Production Technician I    MA   2301.0
# 189      Purinton, Janine  1011022926  Production Technician I    MA   2474.0
# 216  Kinsella, Kathleen     710007401  Production Technician I    MA   2170.0
#
#     Gender MaritalDesc          CitizenDesc        EmploymentStatus  \
# 32       F         NaN           US Citizen                  Active
# ...

# %%
ethnic["MaritalDesc"].mode()
# Out:
# 0    Single
# Name: MaritalDesc, dtype: object

# %%
ethnic['MaritalDesc'].fillna("Single",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['CitizenDesc'].isna()]  # CitizenDesc --- missing values
# Out:
#         Employee_Name       EmpID                 Position State      Zip  \
# 19   Villanueva, Noah  1111030503       Area Sales Manager    ME   4063.0
# 29     Onque, Jasmine  1501072180       Area Sales Manager    FL  33174.0
# 88  Anderson, Linda    1304055947  Production Technician I    MA   1844.0
#
#    Gender MaritalDesc CitizenDesc EmploymentStatus         Department  \
# 19     M       Single         NaN           Active              Sales
# 29      F      Single         NaN           Active              Sales
# 88      F      Single         NaN           Active  Production
#
#     Salaries  age   Race
# 19  25521.82   25  Asian
# 29  53196.72   38  White
# 88  49500.00   25  White

# %%
ethnic["CitizenDesc"].mode()
# Out:
# 0    US Citizen
# Name: CitizenDesc, dtype: object

# %%
ethnic['CitizenDesc'].fillna("US Citizen",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Department'].isna()] # Department --- missing values
# Out:
#          Employee_Name       EmpID                 Position State      Zip  \
# 30         Potts, Xana  1102024106       Area Sales Manager    KY  40220.0
# 47   Petrowsky, Thelma  1108027853             Data Analyst    MA   1886.0
# 69       Morway, Tanya  1001956578         Network Engineer    MA   2048.0
# 91     Desimone, Carl   1501072124  Production Technician I    MA   2061.0
# 190    Rossetti, Bruno  1405067492  Production Technician I    MA   2155.0
#
#     Gender MaritalDesc CitizenDesc        EmploymentStatus Department  \
# 30       F     Married  US Citizen                  Active        NaN
# 47       F     Married  US Citizen                  Active        NaN
# 69       F     Married  US Citizen                  Active        NaN
# 91      M       Single  US Citizen                  Active        NaN
# 190     M       Single  US Citizen  Voluntarily Terminated        NaN
#
#      Salaries  age                       Race
# 30   28919.00   54  Black or African American
# ...

# %%
ethnic["Department"].mode()
# Out:
# 0    Production
# Name: Department, dtype: object

# %%
ethnic['Department'].fillna("Production",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Salaries'].isna()]  # Salaries --- missing values
# Out:
#              Employee_Name       EmpID                  Position State  \
# 3          Howard, Estelle  1211050782  Administrative Assistant    MA
# 21            Costa, Latia  1409070567        Area Sales Manager    CA
# 35   Westinghouse, Matthew  1009919990              BI Developer    MA
# 53         Bramante, Elisa  1006020066    Director of Operations    MA
# 65          Cisco, Anthony  1102024173                IT Support    MA
# 86        Sullivan, Kissy   1405067298        Production Manager    MA
# 101     Theamstern, Sophia  1404066739   Production Technician I    MA
# 120          Cockel, James  1599991009   Production Technician I    MA
# 134    Beatrice, Courtney   1403066194   Production Technician I    MA
# 148   Barone, Francesco  A  1101023679   Production Technician I    MA
# 169      Heitzman, Anthony  1002017900   Production Technician I    MA
# 190        Rossetti, Bruno  1405067492   Production Technician I    MA
#
# ...

# %%
ethnic["Salaries"].mode()
# Out:
# 0      674.28
# 1    27588.40
# Name: Salaries, dtype: float64

# %%
ethnic['Salaries'].fillna(674,inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Race'].isna()]  # Race --- missing values
# Out:
#             Employee_Name       EmpID                  Position State     Zip  \
# 1    LaRotonda, William    1106026572              Accountant I    MA  1460.0
# 22         Fraval, Maruk   1411071302        Area Sales Manager    CT  6050.0
# 67        Gonzalez, Maria  1988299991                IT Support    MA  2472.0
# 107       Fidelia,  Libby  1006020020   Production Technician I    MA  2155.0
# 136      Darson, Jene'ya   1001109612   Production Technician I    MA  2110.0
# 172      Newman, Richard   1302053044   Production Technician I    MA  2136.0
# 217        Lynch, Lindsay  1001138521   Production Technician I    MA  1844.0
# 253        Linden, Mathew  1405067565  Production Technician II    MA  1770.0
# 285         Navathe, Kurt  1009919960       Senior BI Developer    MA  2056.0
#
#     Gender MaritalDesc CitizenDesc        EmploymentStatus         Department  \
# 1       M     Divorced  US Citizen                  Active      Admin Offices
# ...

# %%
ethnic["Race"].mode()
# Out:
# 0    White
# Name: Race, dtype: object

# %%
ethnic['Race'].fillna("White",inplace = True) # replace missing value with mode

# %%
ethnic.isna().sum()
# Out:
# Employee_Name       0
# EmpID               0
# Position            0
# State               0
# Zip                 0
# Gender              0
# MaritalDesc         0
# CitizenDesc         0
# EmploymentStatus    0
# Department          0
# Salaries            0
# age                 0
# Race                0
# dtype: int64

# %% [markdown]
# ### 2.Statistical value

# %%
ethnic = pd.read_excel(r"C:\Users\LENOVO\Downloads\ethnic_diversity.xlsx")
ethnic
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
ethnic.isna().sum()
# Out:
# Employee_Name        0
# EmpID                0
# Position             3
# State                2
# Zip                  2
# Gender               7
# MaritalDesc          9
# CitizenDesc          3
# EmploymentStatus     0
# Department           5
# Salaries            12
# age                  0
# Race                 9
# dtype: int64

# %%
ethnic[ethnic["Position"].isna()]
# Out:
#            Employee_Name       EmpID Position State     Zip Gender  \
# 91       Desimone, Carl   1501072124      NaN    MA  2061.0     M
# 95   Kirill, Alexandra     903013071      NaN    MA  2127.0      F
# 151        Engdahl, Jean  1007020403      NaN   NaN  2026.0     M
#
#     MaritalDesc CitizenDesc        EmploymentStatus         Department  \
# 91          NaN  US Citizen                  Active                NaN
# 95      Married  US Citizen  Voluntarily Terminated  Production
# 151      Single  US Citizen                  Active  Production
#
#      Salaries  age   Race
# 91   15736.71   26  White
# 95   37619.00   44  White
# 151  49808.01   54  White

# %%
ethnic["Position"].mode()  # position ---- missing values
# Out:
# 0    Production Technician I
# Name: Position, dtype: object

# %%
ethnic["Position"].fillna("Production Technician I",inplace = True)  # filling the missing value

# %%
ethnic[ethnic['State'].isna()]  # missing value
ethnic["State"].mode()
# Out:
# 0    MA
# Name: State, dtype: object

# %%
ethnic["State"].fillna("MA",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Zip'].isna()]  # Zip ---missing values
ethnic["Zip"].mean()
# Out:
# 6596.977272727273

# %%
ethnic["Zip"].fillna(6596,inplace = True) # replace missing value with mean

# %%
ethnic[ethnic['Gender'].isna()]  # Gender ---- missing values
ethnic["Gender"].mode()
# Out:
# 0    F
# Name: Gender, dtype: object

# %%
ethnic["Gender"].fillna("F",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['MaritalDesc'].isna()]  # MaritalDesc --- missing values
ethnic["MaritalDesc"].mode()
# Out:
# 0    Single
# Name: MaritalDesc, dtype: object

# %%
ethnic["MaritalDesc"].fillna("Single",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['CitizenDesc'].isna()]  # CitizenDesc --- missing values
ethnic["CitizenDesc"].mode()
# Out:
# 0    US Citizen
# Name: CitizenDesc, dtype: object

# %%
ethnic["CitizenDesc"].fillna("US Citizen",inplace = True) # replace missing value with mode

# %%
ethnic[ethnic['Department'].isna()] # Department --- missing values
ethnic["Department"].mode()
# Out:
# 0    Production
# Name: Department, dtype: object

# %%
ethnic[ethnic['Salaries'].isna()]  # Salaries --- missing values
ethnic["Salaries"].mean()
# Out:
# 36592.22104026846

# %%
ethnic["Salaries"].fillna(36592.22,inplace = True) # replace missing value with mean

# %%
ethnic[ethnic['Race'].isna()]  # Race --- missing values
ethnic["Race"].mode()
# Out:
# 0    White
# Name: Race, dtype: object

# %%
ethnic["Race"].fillna("White",inplace = True) # replace missing value with mode

# %%
ethnic.isna().sum()
# Out:
# Employee_Name       0
# EmpID               0
# Position            0
# State               0
# Zip                 0
# Gender              0
# MaritalDesc         0
# CitizenDesc         0
# EmploymentStatus    0
# Department          0
# Salaries            0
# age                 0
# Race                0
# dtype: int64

# %% [markdown]
# ### 3.Filling  method

# %%
ethnic = pd.read_excel(r"C:\Users\LENOVO\Downloads\ethnic_diversity.xlsx")
ethnic
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
ethnic.isna().sum()
# Out:
# Employee_Name        0
# EmpID                0
# Position             3
# State                2
# Zip                  2
# Gender               7
# MaritalDesc          9
# CitizenDesc          3
# EmploymentStatus     0
# Department           5
# Salaries            12
# age                  0
# Race                 9
# dtype: int64

# %%
ethnic["Position"].fillna(method="ffill",inplace=True)   # position

ethnic["State"].fillna(method="ffill",inplace=True)   # state

ethnic["Zip"].fillna(method="ffill",inplace=True)   # zip

ethnic["Gender"].fillna(method="ffill",inplace=True)   # Gender

ethnic["MaritalDesc"].fillna(method="ffill",inplace=True)   # maritaldesc

ethnic["CitizenDesc"].fillna(method="ffill",inplace=True)   # maritaldesc

ethnic["Department"].fillna(method="ffill",inplace=True)   # department

ethnic["Salaries"].fillna(method="ffill",inplace=True)   # salaries

ethnic["Race"].fillna(method="ffill",inplace=True)   # race

# %%
ethnic.isna().sum()
# Out:
# Employee_Name       0
# EmpID               0
# Position            0
# State               0
# Zip                 0
# Gender              0
# MaritalDesc         0
# CitizenDesc         0
# EmploymentStatus    0
# Department          0
# Salaries            0
# age                 0
# Race                0
# dtype: int64

# %%
ethnic
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %% [markdown]
# ### B) Create pivot table for  position and average salary.

# %%
ethnic.pivot_table(values =  "Salaries",columns = "Position",aggfunc = "mean")
# Out:
# Position  Accountant I  Administrative Assistant  Area Sales Manager  \
# Salaries        674.28                 46747.685        42048.275769
#
# Position  BI Developer  BI Director       CIO  Data Analyst  Data Analyst   \
# Salaries  37449.776667       4160.0  26418.01  37772.945714       42304.75
#
# Position  Data Architect  Database Administrator  ...  \
# Salaries        90016.01               33813.996  ...
#
# Position  Production Technician I  Production Technician II  Sales Manager  \
# Salaries             35136.340787              33803.863333   34093.246667
#
# Position  Senior BI Developer  Shared Services Manager  Software Engineer  \
# Salaries         71293.676667                45262.975       39892.308889
#
# Position  Software Engineering Manager  Sr. Accountant    Sr. DBA  \
# Salaries                       40208.0       27349.755  31954.975
#
# Position  Sr. Network Engineer
# Salaries               28438.6
#
# [1 rows x 31 columns]

# %% [markdown]
# #### C) Group the data using group by as per gender  and average age

# %%
ethnic.groupby(by = "Gender")["age"].mean()
# Out:
# Gender
# F     38.738372
# M     38.732824
# Name: age, dtype: float64
